# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanita-8943/efficientnet_keras_transfer_learning/blob/master/Data_All_Lt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import shutil
import os
import glob
import shutil
import sys
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv (r'/content/drive/MyDrive/All_File_Lt/Data/ดึงรูป_All_Data_Lt.csv')
df
# Out:
#       Fig_Age  Fig_Person  Age(year) Class_Age+Gender Class_Age  Class_Re_0  \
# 0           1           1          7             Y07F       Y07           0
# 1           2           1          7             Y07F       Y07           0
# 2           3           2          7             Y07F       Y07           0
# 3           4           2          7             Y07F       Y07           0
# 4           5           3          7             Y07F       Y07           0
# ...       ...         ...        ...              ...       ...         ...
# 4745      121          77         25             Y25M       Y25          18
# 4746      122          78         25             Y25M       Y25          18
# 4747      123          78         25             Y25M       Y25          18
# 4748      124          79         25             Y25M       Y25          18
# 4749      125          79         25             Y25M       Y25          18
#
#       Class_Re_1       Filename  \
# ...

# %% [markdown]
# ##สร้างโฟลเดอร์

# %%
base_dir = '/content/drive/My Drive/All_File_Lt/TVT_All_Lt'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
train_dir = os.path.join(base_dir, 'train')
os.makedirs(train_dir, exist_ok=True)
validation_dir = os.path.join(base_dir, 'validation')
os.makedirs(validation_dir, exist_ok=True)
test_dir = os.path.join(base_dir, 'test')
os.makedirs(test_dir, exist_ok=True)

# %%
train_Y07_dir = os.path.join(train_dir, 'Y07')
os.makedirs(train_Y07_dir, exist_ok=True)

train_Y08_dir = os.path.join(train_dir, 'Y08')
os.makedirs(train_Y08_dir, exist_ok=True)

train_Y09_dir = os.path.join(train_dir, 'Y09')
os.makedirs(train_Y09_dir, exist_ok=True)

train_Y10_dir = os.path.join(train_dir, 'Y10')
os.makedirs(train_Y10_dir, exist_ok=True)

train_Y11_dir = os.path.join(train_dir, 'Y11')
os.makedirs(train_Y11_dir, exist_ok=True)

train_Y12_dir = os.path.join(train_dir, 'Y12')
os.makedirs(train_Y12_dir, exist_ok=True)

train_Y13_dir = os.path.join(train_dir, 'Y13')
os.makedirs(train_Y13_dir, exist_ok=True)

train_Y14_dir = os.path.join(train_dir, 'Y14')
os.makedirs(train_Y14_dir, exist_ok=True)

train_Y15_dir = os.path.join(train_dir, 'Y15')
os.makedirs(train_Y15_dir, exist_ok=True)

train_Y16_dir = os.path.join(train_dir, 'Y16')
os.makedirs(train_Y16_dir, exist_ok=True)

train_Y17_dir = os.path.join(train_dir, 'Y17')
os.makedirs(train_Y17_dir, exist_ok=True)

train_Y18_dir = os.path.join(train_dir, 'Y18')
os.makedirs(train_Y18_dir, exist_ok=True)

train_Y19_dir = os.path.join(train_dir, 'Y19')
os.makedirs(train_Y19_dir, exist_ok=True)

train_Y20_dir = os.path.join(train_dir, 'Y20')
os.makedirs(train_Y20_dir, exist_ok=True)

train_Y21_dir = os.path.join(train_dir, 'Y21')
os.makedirs(train_Y21_dir, exist_ok=True)

train_Y22_dir = os.path.join(train_dir, 'Y22')
os.makedirs(train_Y22_dir, exist_ok=True)

train_Y23_dir = os.path.join(train_dir, 'Y23')
os.makedirs(train_Y23_dir, exist_ok=True)

train_Y24_dir = os.path.join(train_dir, 'Y24')
os.makedirs(train_Y24_dir, exist_ok=True)

train_Y25_dir = os.path.join(train_dir, 'Y25')
os.makedirs(train_Y25_dir, exist_ok=True)

# %%
validation_Y07_dir = os.path.join(validation_dir, 'Y07')
os.makedirs(validation_Y07_dir, exist_ok=True)

validation_Y08_dir = os.path.join(validation_dir, 'Y08')
os.makedirs(validation_Y08_dir, exist_ok=True)

validation_Y09_dir = os.path.join(validation_dir, 'Y09')
os.makedirs(validation_Y09_dir, exist_ok=True)

validation_Y10_dir = os.path.join(validation_dir, 'Y10')
os.makedirs(validation_Y10_dir, exist_ok=True)

validation_Y11_dir = os.path.join(validation_dir, 'Y11')
os.makedirs(validation_Y11_dir, exist_ok=True)

validation_Y12_dir = os.path.join(validation_dir, 'Y12')
os.makedirs(validation_Y12_dir, exist_ok=True)

validation_Y13_dir = os.path.join(validation_dir, 'Y13')
os.makedirs(validation_Y13_dir, exist_ok=True)

validation_Y14_dir = os.path.join(validation_dir, 'Y14')
os.makedirs(validation_Y14_dir, exist_ok=True)

validation_Y15_dir = os.path.join(validation_dir, 'Y15')
os.makedirs(validation_Y15_dir, exist_ok=True)

validation_Y16_dir = os.path.join(validation_dir, 'Y16')
os.makedirs(validation_Y16_dir, exist_ok=True)

validation_Y17_dir = os.path.join(validation_dir, 'Y17')
os.makedirs(validation_Y17_dir, exist_ok=True)

validation_Y18_dir = os.path.join(validation_dir, 'Y18')
os.makedirs(validation_Y18_dir, exist_ok=True)

validation_Y19_dir = os.path.join(validation_dir, 'Y19')
os.makedirs(validation_Y19_dir, exist_ok=True)

validation_Y20_dir = os.path.join(validation_dir, 'Y20')
os.makedirs(validation_Y20_dir, exist_ok=True)

validation_Y21_dir = os.path.join(validation_dir, 'Y21')
os.makedirs(validation_Y21_dir, exist_ok=True)

validation_Y22_dir = os.path.join(validation_dir, 'Y22')
os.makedirs(validation_Y22_dir, exist_ok=True)

validation_Y23_dir = os.path.join(validation_dir, 'Y23')
os.makedirs(validation_Y23_dir, exist_ok=True)

validation_Y24_dir = os.path.join(validation_dir, 'Y24')
os.makedirs(validation_Y24_dir, exist_ok=True)

validation_Y25_dir = os.path.join(validation_dir, 'Y25')
os.makedirs(validation_Y25_dir, exist_ok=True)

# %%
test_Y07_dir = os.path.join(test_dir, 'Y07')
os.makedirs(test_Y07_dir, exist_ok=True)

test_Y08_dir = os.path.join(test_dir, 'Y08')
os.makedirs(test_Y08_dir, exist_ok=True)

test_Y09_dir = os.path.join(test_dir, 'Y09')
os.makedirs(test_Y09_dir, exist_ok=True)

test_Y10_dir = os.path.join(test_dir, 'Y10')
os.makedirs(test_Y10_dir, exist_ok=True)

test_Y11_dir = os.path.join(test_dir, 'Y11')
os.makedirs(test_Y11_dir, exist_ok=True)

test_Y12_dir = os.path.join(test_dir, 'Y12')
os.makedirs(test_Y12_dir, exist_ok=True)

test_Y13_dir = os.path.join(test_dir, 'Y13')
os.makedirs(test_Y13_dir, exist_ok=True)

test_Y14_dir = os.path.join(test_dir, 'Y14')
os.makedirs(test_Y14_dir, exist_ok=True)

test_Y15_dir = os.path.join(test_dir, 'Y15')
os.makedirs(test_Y15_dir, exist_ok=True)

test_Y16_dir = os.path.join(test_dir, 'Y16')
os.makedirs(test_Y16_dir, exist_ok=True)

test_Y17_dir = os.path.join(test_dir, 'Y17')
os.makedirs(test_Y17_dir, exist_ok=True)

test_Y18_dir = os.path.join(test_dir, 'Y18')
os.makedirs(test_Y18_dir, exist_ok=True)

test_Y19_dir = os.path.join(test_dir, 'Y19')
os.makedirs(test_Y19_dir, exist_ok=True)

test_Y20_dir = os.path.join(test_dir, 'Y20')
os.makedirs(test_Y20_dir, exist_ok=True)

test_Y21_dir = os.path.join(test_dir, 'Y21')
os.makedirs(test_Y21_dir, exist_ok=True)

test_Y22_dir = os.path.join(test_dir, 'Y22')
os.makedirs(test_Y22_dir, exist_ok=True)

test_Y23_dir = os.path.join(test_dir, 'Y23')
os.makedirs(test_Y23_dir, exist_ok=True)

test_Y24_dir = os.path.join(test_dir, 'Y24')
os.makedirs(test_Y24_dir, exist_ok=True)

test_Y25_dir = os.path.join(test_dir, 'Y25')
os.makedirs(test_Y25_dir, exist_ok=True)

# %%
val = df[df['Fig_Age'].between(76,100)]
train = df[df['Fig_Age'].between(1,75)]
test = df[df['Fig_Age'].between(101,125)]

# %%
#Path Train
Y07F_train = train[train['Class_Age+Gender']=='Y07F' ]
Y07F_path_train = Y07F_train['Path_filename'].tolist() 

Y08F_train = train[train['Class_Age+Gender']=='Y08F' ]
Y08F_path_train = Y08F_train['Path_filename'].tolist()

Y09F_train = train[train['Class_Age+Gender']=='Y09F' ]
Y09F_path_train = Y09F_train['Path_filename'].tolist() 

Y10F_train = train[train['Class_Age+Gender']=='Y10F' ]
Y10F_path_train = Y10F_train['Path_filename'].tolist()

Y11F_train = train[train['Class_Age+Gender']=='Y11F' ]
Y11F_path_train = Y11F_train['Path_filename'].tolist()

Y12F_train = train[train['Class_Age+Gender']=='Y12F' ]
Y12F_path_train = Y12F_train['Path_filename'].tolist()

Y13F_train = train[train['Class_Age+Gender']=='Y13F' ]
Y13F_path_train = Y13F_train['Path_filename'].tolist()

Y14F_train = train[train['Class_Age+Gender']=='Y14F' ]
Y14F_path_train = Y14F_train['Path_filename'].tolist()

Y15F_train = train[train['Class_Age+Gender']=='Y15F' ]
Y15F_path_train = Y15F_train['Path_filename'].tolist()

Y16F_train = train[train['Class_Age+Gender']=='Y16F' ]
Y16F_path_train = Y16F_train['Path_filename'].tolist()

Y17F_train = train[train['Class_Age+Gender']=='Y17F' ]
Y17F_path_train = Y17F_train['Path_filename'].tolist()

Y18F_train = train[train['Class_Age+Gender']=='Y18F' ]
Y18F_path_train = Y18F_train['Path_filename'].tolist()

Y19F_train = train[train['Class_Age+Gender']=='Y19F' ]
Y19F_path_train = Y19F_train['Path_filename'].tolist()

Y20F_train = train[train['Class_Age+Gender']=='Y20F' ]
Y20F_path_train = Y20F_train['Path_filename'].tolist()

Y21F_train = train[train['Class_Age+Gender']=='Y21F' ]
Y21F_path_train = Y21F_train['Path_filename'].tolist()

Y22F_train = train[train['Class_Age+Gender']=='Y22F' ]
Y22F_path_train = Y22F_train['Path_filename'].tolist()

Y23F_train = train[train['Class_Age+Gender']=='Y23F' ]
Y23F_path_train = Y23F_train['Path_filename'].tolist()

Y24F_train = train[train['Class_Age+Gender']=='Y24F' ]
Y24F_path_train = Y24F_train['Path_filename'].tolist()

Y25F_train = train[train['Class_Age+Gender']=='Y25F' ]
Y25F_path_train = Y25F_train['Path_filename'].tolist()

Y07M_train = train[train['Class_Age+Gender']=='Y07M' ]
Y07M_path_train = Y07M_train['Path_filename'].tolist() 

Y08M_train = train[train['Class_Age+Gender']=='Y08M' ]
Y08M_path_train = Y08M_train['Path_filename'].tolist()

Y09M_train = train[train['Class_Age+Gender']=='Y09M' ]
Y09M_path_train = Y09M_train['Path_filename'].tolist() 

Y10M_train = train[train['Class_Age+Gender']=='Y10M' ]
Y10M_path_train = Y10M_train['Path_filename'].tolist()

Y11M_train = train[train['Class_Age+Gender']=='Y11M' ]
Y11M_path_train = Y11M_train['Path_filename'].tolist()

Y12M_train = train[train['Class_Age+Gender']=='Y12M' ]
Y12M_path_train = Y12M_train['Path_filename'].tolist()

Y13M_train = train[train['Class_Age+Gender']=='Y13M' ]
Y13M_path_train = Y13M_train['Path_filename'].tolist()

Y14M_train = train[train['Class_Age+Gender']=='Y14M' ]
Y14M_path_train = Y14M_train['Path_filename'].tolist()

Y15M_train = train[train['Class_Age+Gender']=='Y15M' ]
Y15M_path_train = Y15M_train['Path_filename'].tolist()

Y16M_train = train[train['Class_Age+Gender']=='Y16M' ]
Y16M_path_train = Y16M_train['Path_filename'].tolist()

Y17M_train = train[train['Class_Age+Gender']=='Y17M' ]
Y17M_path_train = Y17M_train['Path_filename'].tolist()

Y18M_train = train[train['Class_Age+Gender']=='Y18M' ]
Y18M_path_train = Y18M_train['Path_filename'].tolist()

Y19M_train = train[train['Class_Age+Gender']=='Y19M' ]
Y19M_path_train = Y19M_train['Path_filename'].tolist()

Y20M_train = train[train['Class_Age+Gender']=='Y20M' ]
Y20M_path_train = Y20M_train['Path_filename'].tolist()

Y21M_train = train[train['Class_Age+Gender']=='Y21M' ]
Y21M_path_train = Y21M_train['Path_filename'].tolist()

Y22M_train = train[train['Class_Age+Gender']=='Y22M' ]
Y22M_path_train = Y22M_train['Path_filename'].tolist()

Y23M_train = train[train['Class_Age+Gender']=='Y23M' ]
Y23M_path_train = Y23M_train['Path_filename'].tolist()

Y24M_train = train[train['Class_Age+Gender']=='Y24M' ]
Y24M_path_train = Y24M_train['Path_filename'].tolist()

Y25M_train = train[train['Class_Age+Gender']=='Y25M' ]
Y25M_path_train = Y25M_train['Path_filename'].tolist()

# %%
#Path val
Y07F_val = val[val['Class_Age+Gender']=='Y07F' ]
Y07F_path_val = Y07F_val['Path_filename'].tolist() 

Y08F_val = val[val['Class_Age+Gender']=='Y08F' ]
Y08F_path_val = Y08F_val['Path_filename'].tolist()

Y09F_val = val[val['Class_Age+Gender']=='Y09F' ]
Y09F_path_val = Y09F_val['Path_filename'].tolist() 

Y10F_val = val[val['Class_Age+Gender']=='Y10F' ]
Y10F_path_val = Y10F_val['Path_filename'].tolist()

Y11F_val = val[val['Class_Age+Gender']=='Y11F' ]
Y11F_path_val = Y11F_val['Path_filename'].tolist()

Y12F_val = val[val['Class_Age+Gender']=='Y12F' ]
Y12F_path_val = Y12F_val['Path_filename'].tolist()

Y13F_val = val[val['Class_Age+Gender']=='Y13F' ]
Y13F_path_val = Y13F_val['Path_filename'].tolist()

Y14F_val = val[val['Class_Age+Gender']=='Y14F' ]
Y14F_path_val = Y14F_val['Path_filename'].tolist()

Y15F_val = val[val['Class_Age+Gender']=='Y15F' ]
Y15F_path_val = Y15F_val['Path_filename'].tolist()

Y16F_val = val[val['Class_Age+Gender']=='Y16F' ]
Y16F_path_val = Y16F_val['Path_filename'].tolist()

Y17F_val = val[val['Class_Age+Gender']=='Y17F' ]
Y17F_path_val = Y17F_val['Path_filename'].tolist()

Y18F_val = val[val['Class_Age+Gender']=='Y18F' ]
Y18F_path_val = Y18F_val['Path_filename'].tolist()

Y19F_val = val[val['Class_Age+Gender']=='Y19F' ]
Y19F_path_val = Y19F_val['Path_filename'].tolist()

Y20F_val = val[val['Class_Age+Gender']=='Y20F' ]
Y20F_path_val = Y20F_val['Path_filename'].tolist()

Y21F_val = val[val['Class_Age+Gender']=='Y21F' ]
Y21F_path_val = Y21F_val['Path_filename'].tolist()

Y22F_val = val[val['Class_Age+Gender']=='Y22F' ]
Y22F_path_val = Y22F_val['Path_filename'].tolist()

Y23F_val = val[val['Class_Age+Gender']=='Y23F' ]
Y23F_path_val = Y23F_val['Path_filename'].tolist()

Y24F_val = val[val['Class_Age+Gender']=='Y24F' ]
Y24F_path_val = Y24F_val['Path_filename'].tolist()

Y25F_val = val[val['Class_Age+Gender']=='Y25F' ]
Y25F_path_val = Y25F_val['Path_filename'].tolist()

Y07M_val = val[val['Class_Age+Gender']=='Y07M' ]
Y07M_path_val = Y07M_val['Path_filename'].tolist() 

Y08M_val = val[val['Class_Age+Gender']=='Y08M' ]
Y08M_path_val = Y08M_val['Path_filename'].tolist()

Y09M_val = val[val['Class_Age+Gender']=='Y09M' ]
Y09M_path_val = Y09M_val['Path_filename'].tolist() 

Y10M_val = val[val['Class_Age+Gender']=='Y10M' ]
Y10M_path_val = Y10M_val['Path_filename'].tolist()

Y11M_val = val[val['Class_Age+Gender']=='Y11M' ]
Y11M_path_val = Y11M_val['Path_filename'].tolist()

Y12M_val = val[val['Class_Age+Gender']=='Y12M' ]
Y12M_path_val = Y12M_val['Path_filename'].tolist()

Y13M_val = val[val['Class_Age+Gender']=='Y13M' ]
Y13M_path_val = Y13M_val['Path_filename'].tolist()

Y14M_val = val[val['Class_Age+Gender']=='Y14M' ]
Y14M_path_val = Y14M_val['Path_filename'].tolist()

Y15M_val = val[val['Class_Age+Gender']=='Y15M' ]
Y15M_path_val = Y15M_val['Path_filename'].tolist()

Y16M_val = val[val['Class_Age+Gender']=='Y16M' ]
Y16M_path_val = Y16M_val['Path_filename'].tolist()

Y17M_val = val[val['Class_Age+Gender']=='Y17M' ]
Y17M_path_val = Y17M_val['Path_filename'].tolist()

Y18M_val = val[val['Class_Age+Gender']=='Y18M' ]
Y18M_path_val = Y18M_val['Path_filename'].tolist()

Y19M_val = val[val['Class_Age+Gender']=='Y19M' ]
Y19M_path_val = Y19M_val['Path_filename'].tolist()

Y20M_val = val[val['Class_Age+Gender']=='Y20M' ]
Y20M_path_val = Y20M_val['Path_filename'].tolist()

Y21M_val = val[val['Class_Age+Gender']=='Y21M' ]
Y21M_path_val = Y21M_val['Path_filename'].tolist()

Y22M_val = val[val['Class_Age+Gender']=='Y22M' ]
Y22M_path_val = Y22M_val['Path_filename'].tolist()

Y23M_val = val[val['Class_Age+Gender']=='Y23M' ]
Y23M_path_val = Y23M_val['Path_filename'].tolist()

Y24M_val = val[val['Class_Age+Gender']=='Y24M' ]
Y24M_path_val = Y24M_val['Path_filename'].tolist()

Y25M_val = val[val['Class_Age+Gender']=='Y25M' ]
Y25M_path_val = Y25M_val['Path_filename'].tolist()

# %%
Y07F_test = test[test['Class_Age+Gender']=='Y07F' ]
Y07F_path_test = Y07F_test['Path_filename'].tolist() 

Y08F_test = test[test['Class_Age+Gender']=='Y08F' ]
Y08F_path_test = Y08F_test['Path_filename'].tolist()

Y09F_test = test[test['Class_Age+Gender']=='Y09F' ]
Y09F_path_test = Y09F_test['Path_filename'].tolist() 

Y10F_test = test[test['Class_Age+Gender']=='Y10F' ]
Y10F_path_test = Y10F_test['Path_filename'].tolist()

Y11F_test = test[test['Class_Age+Gender']=='Y11F' ]
Y11F_path_test = Y11F_test['Path_filename'].tolist()

Y12F_test = test[test['Class_Age+Gender']=='Y12F' ]
Y12F_path_test = Y12F_test['Path_filename'].tolist()

Y13F_test = test[test['Class_Age+Gender']=='Y13F' ]
Y13F_path_test = Y13F_test['Path_filename'].tolist()

Y14F_test = test[test['Class_Age+Gender']=='Y14F' ]
Y14F_path_test = Y14F_test['Path_filename'].tolist()

Y15F_test = test[test['Class_Age+Gender']=='Y15F' ]
Y15F_path_test = Y15F_test['Path_filename'].tolist()

Y16F_test = test[test['Class_Age+Gender']=='Y16F' ]
Y16F_path_test = Y16F_test['Path_filename'].tolist()

Y17F_test = test[test['Class_Age+Gender']=='Y17F' ]
Y17F_path_test = Y17F_test['Path_filename'].tolist()

Y18F_test = test[test['Class_Age+Gender']=='Y18F' ]
Y18F_path_test = Y18F_test['Path_filename'].tolist()

Y19F_test = test[test['Class_Age+Gender']=='Y19F' ]
Y19F_path_test = Y19F_test['Path_filename'].tolist()

Y20F_test = test[test['Class_Age+Gender']=='Y20F' ]
Y20F_path_test = Y20F_test['Path_filename'].tolist()

Y21F_test = test[test['Class_Age+Gender']=='Y21F' ]
Y21F_path_test = Y21F_test['Path_filename'].tolist()

Y22F_test = test[test['Class_Age+Gender']=='Y22F' ]
Y22F_path_test = Y22F_test['Path_filename'].tolist()

Y23F_test = test[test['Class_Age+Gender']=='Y23F' ]
Y23F_path_test = Y23F_test['Path_filename'].tolist()

Y24F_test = test[test['Class_Age+Gender']=='Y24F' ]
Y24F_path_test = Y24F_test['Path_filename'].tolist()

Y25F_test = test[test['Class_Age+Gender']=='Y25F' ]
Y25F_path_test = Y25F_test['Path_filename'].tolist()

Y07M_test = test[test['Class_Age+Gender']=='Y07M' ]
Y07M_path_test = Y07M_test['Path_filename'].tolist() 

Y08M_test = test[test['Class_Age+Gender']=='Y08M' ]
Y08M_path_test = Y08M_test['Path_filename'].tolist()

Y09M_test = test[test['Class_Age+Gender']=='Y09M' ]
Y09M_path_test = Y09M_test['Path_filename'].tolist() 

Y10M_test = test[test['Class_Age+Gender']=='Y10M' ]
Y10M_path_test = Y10M_test['Path_filename'].tolist()

Y11M_test = test[test['Class_Age+Gender']=='Y11M' ]
Y11M_path_test = Y11M_test['Path_filename'].tolist()

Y12M_test = test[test['Class_Age+Gender']=='Y12M' ]
Y12M_path_test = Y12M_test['Path_filename'].tolist()

Y13M_test = test[test['Class_Age+Gender']=='Y13M' ]
Y13M_path_test = Y13M_test['Path_filename'].tolist()

Y14M_test = test[test['Class_Age+Gender']=='Y14M' ]
Y14M_path_test = Y14M_test['Path_filename'].tolist()

Y15M_test = test[test['Class_Age+Gender']=='Y15M' ]
Y15M_path_test = Y15M_test['Path_filename'].tolist()

Y16M_test = test[test['Class_Age+Gender']=='Y16M' ]
Y16M_path_test = Y16M_test['Path_filename'].tolist()

Y17M_test = test[test['Class_Age+Gender']=='Y17M' ]
Y17M_path_test = Y17M_test['Path_filename'].tolist()

Y18M_test = test[test['Class_Age+Gender']=='Y18M' ]
Y18M_path_test = Y18M_test['Path_filename'].tolist()

Y19M_test = test[test['Class_Age+Gender']=='Y19M' ]
Y19M_path_test = Y19M_test['Path_filename'].tolist()

Y20M_test = test[test['Class_Age+Gender']=='Y20M' ]
Y20M_path_test = Y20M_test['Path_filename'].tolist()

Y21M_test = test[test['Class_Age+Gender']=='Y21M' ]
Y21M_path_test = Y21M_test['Path_filename'].tolist()

Y22M_test = test[test['Class_Age+Gender']=='Y22M' ]
Y22M_path_test = Y22M_test['Path_filename'].tolist()

Y23M_test = test[test['Class_Age+Gender']=='Y23M' ]
Y23M_path_test = Y23M_test['Path_filename'].tolist()

Y24M_test = test[test['Class_Age+Gender']=='Y24M' ]
Y24M_path_test = Y24M_test['Path_filename'].tolist()

Y25M_test = test[test['Class_Age+Gender']=='Y25M' ]
Y25M_path_test = Y25M_test['Path_filename'].tolist()

# %% [markdown]
# ##ดึงรูปเข้าโฟลเดอร์

# %%
# fnames = Y07F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12F_path_train
for fname in fnames:
    dst = os.path.join(train_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25F_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y07M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12M_path_train
for fname in fnames:
    dst = os.path.join(train_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25M_path_train
# for fname in fnames:
#     dst = os.path.join(train_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# %%
# fnames = Y07F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12F_path_val
for fname in fnames:
    dst = os.path.join(validation_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25F_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y07M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12M_path_val
for fname in fnames:
    dst = os.path.join(validation_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25M_path_val
# for fname in fnames:
#     dst = os.path.join(validation_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# %%
# fnames = Y07F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12F_path_test
for fname in fnames:
    dst = os.path.join(test_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25F_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y07M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y07_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y08M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y08_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y09M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y09_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y10M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y10_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y11M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y11_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

fnames = Y12M_path_test
for fname in fnames:
    dst = os.path.join(test_Y12_dir, os.path.basename(fname))
    shutil.copyfile(fname, dst)

# fnames = Y13M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y13_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y14M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y14_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y15M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y15_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y16M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y16_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y17M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y17_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y18M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y18_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y19M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y19_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y20M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y20_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y21M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y21_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y22M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y22_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y23M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y23_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y24M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y24_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# fnames = Y25M_path_test
# for fname in fnames:
#     dst = os.path.join(test_Y25_dir, os.path.basename(fname))
#     shutil.copyfile(fname, dst)

# %%
print('total training 7Y images:', len(os.listdir(train_Y07_dir))) 
print('total training 8Y images:', len(os.listdir(train_Y08_dir)))
print('total training 9Y images:', len(os.listdir(train_Y09_dir))) 
print('total training 10Y images:', len(os.listdir(train_Y10_dir)))
print('total training 11Y images:', len(os.listdir(train_Y11_dir)))
print('total training 12Y images:', len(os.listdir(train_Y12_dir)))
print('total training 13Y images:', len(os.listdir(train_Y13_dir)))
print('total training 14Y images:', len(os.listdir(train_Y14_dir)))
print('total training 15Y images:', len(os.listdir(train_Y15_dir)))
print('total training 16Y images:', len(os.listdir(train_Y16_dir)))
print('total training 17Y images:', len(os.listdir(train_Y17_dir)))
print('total training 18Y images:', len(os.listdir(train_Y18_dir)))
print('total training 19Y images:', len(os.listdir(train_Y19_dir)))
print('total training 20Y images:', len(os.listdir(train_Y20_dir)))
print('total training 21Y images:', len(os.listdir(train_Y21_dir)))
print('total training 22Y images:', len(os.listdir(train_Y22_dir)))
print('total training 23Y images:', len(os.listdir(train_Y23_dir)))
print('total training 24Y images:', len(os.listdir(train_Y24_dir)))
print('total training 25Y images:', len(os.listdir(train_Y25_dir)))


print('total validation 7Y images:', len(os.listdir(validation_Y07_dir))) 
print('total validation 8Y images:', len(os.listdir(validation_Y08_dir)))
print('total validation 9Y images:', len(os.listdir(validation_Y09_dir))) 
print('total validation 10Y images:', len(os.listdir(validation_Y10_dir)))
print('total validation 11Y images:', len(os.listdir(validation_Y11_dir)))
print('total validation 12Y images:', len(os.listdir(validation_Y12_dir)))
print('total validation 13Y images:', len(os.listdir(validation_Y13_dir)))
print('total validation 14Y images:', len(os.listdir(validation_Y14_dir)))
print('total validation 15Y images:', len(os.listdir(validation_Y15_dir)))
print('total validation 16Y images:', len(os.listdir(validation_Y16_dir)))
print('total validation 17Y images:', len(os.listdir(validation_Y17_dir)))
print('total validation 18Y images:', len(os.listdir(validation_Y18_dir)))
print('total validation 19Y images:', len(os.listdir(validation_Y19_dir)))
print('total validation 20Y images:', len(os.listdir(validation_Y20_dir)))
print('total validation 21Y images:', len(os.listdir(validation_Y21_dir)))
print('total validation 22Y images:', len(os.listdir(validation_Y22_dir)))
print('total validation 23Y images:', len(os.listdir(validation_Y23_dir)))
print('total validation 24Y images:', len(os.listdir(validation_Y24_dir)))
print('total validation 25Y images:', len(os.listdir(validation_Y25_dir)))

print('total test 7Y images:', len(os.listdir(test_Y07_dir))) 
print('total test 8Y images:', len(os.listdir(test_Y08_dir)))
print('total test 9Y images:', len(os.listdir(test_Y09_dir))) 
print('total test 10Y images:', len(os.listdir(test_Y10_dir)))
print('total test 11Y images:', len(os.listdir(test_Y11_dir)))
print('total test 12Y images:', len(os.listdir(test_Y12_dir)))
print('total test 13Y images:', len(os.listdir(test_Y13_dir)))
print('total test 14Y images:', len(os.listdir(test_Y14_dir)))
print('total test 15Y images:', len(os.listdir(test_Y15_dir)))
print('total test 16Y images:', len(os.listdir(test_Y16_dir)))
print('total test 17Y images:', len(os.listdir(test_Y17_dir)))
print('total test 18Y images:', len(os.listdir(test_Y18_dir)))
print('total test 19Y images:', len(os.listdir(test_Y19_dir)))
print('total test 20Y images:', len(os.listdir(test_Y20_dir)))
print('total test 21Y images:', len(os.listdir(test_Y21_dir)))
print('total test 22Y images:', len(os.listdir(test_Y22_dir)))
print('total test 23Y images:', len(os.listdir(test_Y23_dir)))
print('total test 24Y images:', len(os.listdir(test_Y24_dir)))
print('total test 25Y images:', len(os.listdir(test_Y25_dir)))
# Out:
# total training 7Y images: 150
# total training 8Y images: 150
# total training 9Y images: 150
# total training 10Y images: 150
# total training 11Y images: 150
# total training 12Y images: 150
# total training 13Y images: 150
# total training 14Y images: 150
# total training 15Y images: 150
# total training 16Y images: 150
# total training 17Y images: 150
# total training 18Y images: 150
# total training 19Y images: 150
# total training 20Y images: 150
# total training 21Y images: 150
# total training 22Y images: 150
# total training 23Y images: 150
# total training 24Y images: 150
# total training 25Y images: 150
# total validation 7Y images: 50
# total validation 8Y images: 50
# total validation 9Y images: 50
# total validation 10Y images: 50
# total validation 11Y images: 50
# total validation 12Y images: 50
# total validation 13Y images: 50
# total validation 14Y images: 50
# total validation 15Y images: 50
# total validation 16Y images: 50
# total validation 17Y images: 50
# ...

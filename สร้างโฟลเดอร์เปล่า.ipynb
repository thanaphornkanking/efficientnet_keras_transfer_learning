# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanita-8943/efficientnet_keras_transfer_learning/blob/master/%E0%B8%AA%E0%B8%A3%E0%B9%89%E0%B8%B2%E0%B8%87%E0%B9%82%E0%B8%9F%E0%B8%A5%E0%B9%80%E0%B8%94%E0%B8%AD%E0%B8%A3%E0%B9%8C%E0%B9%80%E0%B8%9B%E0%B8%A5%E0%B9%88%E0%B8%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import shutil
import os
import glob
import shutil
import sys
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv (r'/content/drive/MyDrive/cut_panoramic/Data/New_Data_Gender.csv')
df
# Out:
#       Fig_Age  Fig_Person_Sex  Age(year) Class  Class_Re       Filename  \
# 0           1               1          7  Y07F         0         V1.jpg
# 1           2               1          7  Y07F         0    Flip_V1.jpg
# 2           3               2          7  Y07F         0         V2.jpg
# 3           4               2          7  Y07F         0    Flip_V2.jpg
# 4           5               3          7  Y07F         0         V3.jpg
# ...       ...             ...        ...   ...       ...            ...
# 4745      121              77         25  Y25M         1  Flip_J463.jpg
# 4746      122              78         25  Y25M         1       J464.jpg
# 4747      123              78         25  Y25M         1  Flip_J464.jpg
# 4748      124              79         25  Y25M         1       J465.jpg
# 4749      125              79         25  Y25M         1  Flip_J465.jpg
#
#                                           Path_filename     Sex Floder
# ...

# %% [markdown]
# ##สร้างโฟลเดอร์

# %%
base_dir = '/content/drive/My Drive/Lt_cut_panoramic'
os.makedirs(base_dir, exist_ok=True)

# Directories for our training,
# validation and test splits
Y07_dir = os.path.join(base_dir, '7 year')
os.makedirs(Y07_dir, exist_ok=True)
Y08_dir = os.path.join(base_dir, '8 year')
os.makedirs(Y07_dir, exist_ok=True)
Y09_dir = os.path.join(base_dir, '9 year')
os.makedirs(Y09_dir, exist_ok=True)
Y10_dir = os.path.join(base_dir, '10 year')
os.makedirs(Y10_dir, exist_ok=True)
Y11_dir = os.path.join(base_dir, '11 year')
os.makedirs(Y11_dir, exist_ok=True)
Y12_dir = os.path.join(base_dir, '12 year')
os.makedirs(Y12_dir, exist_ok=True)
Y13_dir = os.path.join(base_dir, '13 year')
os.makedirs(Y13_dir, exist_ok=True)
Y14_dir = os.path.join(base_dir, '14 year')
os.makedirs(Y14_dir, exist_ok=True)
Y15_dir = os.path.join(base_dir, '15 year')
os.makedirs(Y15_dir, exist_ok=True)
Y16_dir = os.path.join(base_dir, '16 year')
os.makedirs(Y16_dir, exist_ok=True)
Y17_dir = os.path.join(base_dir, '17 year')
os.makedirs(Y17_dir, exist_ok=True)
Y18_dir = os.path.join(base_dir, '18 year')
os.makedirs(Y18_dir, exist_ok=True)
Y19_dir = os.path.join(base_dir, '19 year')
os.makedirs(Y19_dir, exist_ok=True)
Y20_dir = os.path.join(base_dir, '20 year')
os.makedirs(Y20_dir, exist_ok=True)
Y21_dir = os.path.join(base_dir, '21 year')
os.makedirs(Y21_dir, exist_ok=True)
Y22_dir = os.path.join(base_dir, '22 year')
os.makedirs(Y22_dir, exist_ok=True)
Y23_dir = os.path.join(base_dir, '23 year')
os.makedirs(Y23_dir, exist_ok=True)
Y24_dir = os.path.join(base_dir, '24 year')
os.makedirs(Y24_dir, exist_ok=True)
Y25_dir = os.path.join(base_dir, '25 year')
os.makedirs(Y25_dir, exist_ok=True)

# %%
train_Y07F_dir = os.path.join(Y07_dir, '7Y - F')
os.makedirs(train_Y07F_dir, exist_ok=True)
Both_Y07F_dir = os.path.join(train_Y07F_dir, 'Both')
os.makedirs(Both_Y07F_dir, exist_ok=True)
Rt_Y07F_dir = os.path.join(train_Y07F_dir, 'Rt')
os.makedirs(Rt_Y07F_dir, exist_ok=True)
Lt_Y07F_dir = os.path.join(train_Y07F_dir, 'Lt')
os.makedirs(Lt_Y07F_dir, exist_ok=True)


train_Y07M_dir = os.path.join(Y07_dir, '7Y - M')
os.makedirs(train_Y07M_dir, exist_ok=True)

Both_Y07M_dir = os.path.join(train_Y07M_dir, 'Both')
os.makedirs(Both_Y07M_dir, exist_ok=True)
Rt_Y07M_dir = os.path.join(train_Y07M_dir, 'Rt')
os.makedirs(Rt_Y07M_dir, exist_ok=True)
Lt_Y07M_dir = os.path.join(train_Y07M_dir, 'Lt')
os.makedirs(Lt_Y07M_dir, exist_ok=True)

# %%
train_Y08F_dir = os.path.join(Y08_dir, '8Y - F')
os.makedirs(train_Y08F_dir, exist_ok=True)
Both_Y08F_dir = os.path.join(train_Y08F_dir, 'Both')
os.makedirs(Both_Y08F_dir, exist_ok=True)
Rt_Y08F_dir = os.path.join(train_Y08F_dir, 'Rt')
os.makedirs(Rt_Y08F_dir, exist_ok=True)
Lt_Y08F_dir = os.path.join(train_Y08F_dir, 'Lt')
os.makedirs(Lt_Y08F_dir, exist_ok=True)


train_Y08M_dir = os.path.join(Y08_dir, '8Y - M')
os.makedirs(train_Y08M_dir, exist_ok=True)

Both_Y08M_dir = os.path.join(train_Y08M_dir, 'Both')
os.makedirs(Both_Y08M_dir, exist_ok=True)
Rt_Y08M_dir = os.path.join(train_Y08M_dir, 'Rt')
os.makedirs(Rt_Y08M_dir, exist_ok=True)
Lt_Y08M_dir = os.path.join(train_Y08M_dir, 'Lt')
os.makedirs(Lt_Y08M_dir, exist_ok=True)

# %%
train_Y09F_dir = os.path.join(Y09_dir, '9Y - F')
os.makedirs(train_Y09F_dir, exist_ok=True)
Both_Y09F_dir = os.path.join(train_Y09F_dir, 'Both')
os.makedirs(Both_Y09F_dir, exist_ok=True)
Rt_Y09F_dir = os.path.join(train_Y09F_dir, 'Rt')
os.makedirs(Rt_Y09F_dir, exist_ok=True)
Lt_Y09F_dir = os.path.join(train_Y09F_dir, 'Lt')
os.makedirs(Lt_Y09F_dir, exist_ok=True)


train_Y09M_dir = os.path.join(Y09_dir, '9Y - M')
os.makedirs(train_Y09M_dir, exist_ok=True)

Both_Y09M_dir = os.path.join(train_Y09M_dir, 'Both')
os.makedirs(Both_Y09M_dir, exist_ok=True)
Rt_Y09M_dir = os.path.join(train_Y09M_dir, 'Rt')
os.makedirs(Rt_Y09M_dir, exist_ok=True)
Lt_Y09M_dir = os.path.join(train_Y09M_dir, 'Lt')
os.makedirs(Lt_Y09M_dir, exist_ok=True)

# %%
train_Y10F_dir = os.path.join(Y10_dir, '10Y - F')
os.makedirs(train_Y10F_dir, exist_ok=True)
Both_Y10F_dir = os.path.join(train_Y10F_dir, 'Both')
os.makedirs(Both_Y10F_dir, exist_ok=True)
Rt_Y10F_dir = os.path.join(train_Y10F_dir, 'Rt')
os.makedirs(Rt_Y10F_dir, exist_ok=True)
Lt_Y10F_dir = os.path.join(train_Y10F_dir, 'Lt')
os.makedirs(Lt_Y10F_dir, exist_ok=True)


train_Y10M_dir = os.path.join(Y10_dir, '10Y - M')
os.makedirs(train_Y10M_dir, exist_ok=True)

Both_Y10M_dir = os.path.join(train_Y10M_dir, 'Both')
os.makedirs(Both_Y10M_dir, exist_ok=True)
Rt_Y10M_dir = os.path.join(train_Y10M_dir, 'Rt')
os.makedirs(Rt_Y10M_dir, exist_ok=True)
Lt_Y10M_dir = os.path.join(train_Y10M_dir, 'Lt')
os.makedirs(Lt_Y10M_dir, exist_ok=True)

# %%
train_Y11F_dir = os.path.join(Y11_dir, '11Y - F')
os.makedirs(train_Y11F_dir, exist_ok=True)
Both_Y11F_dir = os.path.join(train_Y11F_dir, 'Both')
os.makedirs(Both_Y11F_dir, exist_ok=True)
Rt_Y11F_dir = os.path.join(train_Y11F_dir, 'Rt')
os.makedirs(Rt_Y11F_dir, exist_ok=True)
Lt_Y11F_dir = os.path.join(train_Y11F_dir, 'Lt')
os.makedirs(Lt_Y11F_dir, exist_ok=True)


train_Y11M_dir = os.path.join(Y11_dir, '11Y - M')
os.makedirs(train_Y11M_dir, exist_ok=True)

Both_Y11M_dir = os.path.join(train_Y11M_dir, 'Both')
os.makedirs(Both_Y11M_dir, exist_ok=True)
Rt_Y11M_dir = os.path.join(train_Y11M_dir, 'Rt')
os.makedirs(Rt_Y11M_dir, exist_ok=True)
Lt_Y11M_dir = os.path.join(train_Y11M_dir, 'Lt')
os.makedirs(Lt_Y11M_dir, exist_ok=True)

# %%
train_Y12F_dir = os.path.join(Y12_dir, '12Y - F')
os.makedirs(train_Y12F_dir, exist_ok=True)
Both_Y12F_dir = os.path.join(train_Y12F_dir, 'Both')
os.makedirs(Both_Y12F_dir, exist_ok=True)
Rt_Y12F_dir = os.path.join(train_Y12F_dir, 'Rt')
os.makedirs(Rt_Y12F_dir, exist_ok=True)
Lt_Y12F_dir = os.path.join(train_Y12F_dir, 'Lt')
os.makedirs(Lt_Y12F_dir, exist_ok=True)


train_Y12M_dir = os.path.join(Y12_dir, '12Y - M')
os.makedirs(train_Y12M_dir, exist_ok=True)

Both_Y12M_dir = os.path.join(train_Y12M_dir, 'Both')
os.makedirs(Both_Y12M_dir, exist_ok=True)
Rt_Y12M_dir = os.path.join(train_Y12M_dir, 'Rt')
os.makedirs(Rt_Y12M_dir, exist_ok=True)
Lt_Y12M_dir = os.path.join(train_Y12M_dir, 'Lt')
os.makedirs(Lt_Y12M_dir, exist_ok=True)

# %%
train_Y13F_dir = os.path.join(Y13_dir, '13Y - F')
os.makedirs(train_Y13F_dir, exist_ok=True)
Both_Y13F_dir = os.path.join(train_Y13F_dir, 'Both')
os.makedirs(Both_Y13F_dir, exist_ok=True)
Rt_Y13F_dir = os.path.join(train_Y13F_dir, 'Rt')
os.makedirs(Rt_Y13F_dir, exist_ok=True)
Lt_Y13F_dir = os.path.join(train_Y13F_dir, 'Lt')
os.makedirs(Lt_Y13F_dir, exist_ok=True)


train_Y13M_dir = os.path.join(Y13_dir, '13Y - M')
os.makedirs(train_Y13M_dir, exist_ok=True)

Both_Y13M_dir = os.path.join(train_Y13M_dir, 'Both')
os.makedirs(Both_Y13M_dir, exist_ok=True)
Rt_Y13M_dir = os.path.join(train_Y13M_dir, 'Rt')
os.makedirs(Rt_Y13M_dir, exist_ok=True)
Lt_Y13M_dir = os.path.join(train_Y13M_dir, 'Lt')
os.makedirs(Lt_Y13M_dir, exist_ok=True)

# %%
train_Y14F_dir = os.path.join(Y14_dir, '14Y - F')
os.makedirs(train_Y14F_dir, exist_ok=True)
Both_Y14F_dir = os.path.join(train_Y14F_dir, 'Both')
os.makedirs(Both_Y14F_dir, exist_ok=True)
Rt_Y14F_dir = os.path.join(train_Y14F_dir, 'Rt')
os.makedirs(Rt_Y14F_dir, exist_ok=True)
Lt_Y14F_dir = os.path.join(train_Y14F_dir, 'Lt')
os.makedirs(Lt_Y14F_dir, exist_ok=True)


train_Y14M_dir = os.path.join(Y14_dir, '14Y - M')
os.makedirs(train_Y14M_dir, exist_ok=True)

Both_Y14M_dir = os.path.join(train_Y14M_dir, 'Both')
os.makedirs(Both_Y14M_dir, exist_ok=True)
Rt_Y14M_dir = os.path.join(train_Y14M_dir, 'Rt')
os.makedirs(Rt_Y14M_dir, exist_ok=True)
Lt_Y14M_dir = os.path.join(train_Y14M_dir, 'Lt')
os.makedirs(Lt_Y14M_dir, exist_ok=True)

# %%
train_Y15F_dir = os.path.join(Y15_dir, '15Y - F')
os.makedirs(train_Y15F_dir, exist_ok=True)
Both_Y15F_dir = os.path.join(train_Y15F_dir, 'Both')
os.makedirs(Both_Y15F_dir, exist_ok=True)
Rt_Y15F_dir = os.path.join(train_Y15F_dir, 'Rt')
os.makedirs(Rt_Y15F_dir, exist_ok=True)
Lt_Y15F_dir = os.path.join(train_Y15F_dir, 'Lt')
os.makedirs(Lt_Y15F_dir, exist_ok=True)


train_Y15M_dir = os.path.join(Y15_dir, '15Y - M')
os.makedirs(train_Y15M_dir, exist_ok=True)

Both_Y15M_dir = os.path.join(train_Y15M_dir, 'Both')
os.makedirs(Both_Y15M_dir, exist_ok=True)
Rt_Y15M_dir = os.path.join(train_Y15M_dir, 'Rt')
os.makedirs(Rt_Y15M_dir, exist_ok=True)
Lt_Y15M_dir = os.path.join(train_Y15M_dir, 'Lt')
os.makedirs(Lt_Y15M_dir, exist_ok=True)

# %%
train_Y16F_dir = os.path.join(Y16_dir, '16Y - F')
os.makedirs(train_Y16F_dir, exist_ok=True)
Both_Y16F_dir = os.path.join(train_Y16F_dir, 'Both')
os.makedirs(Both_Y16F_dir, exist_ok=True)
Rt_Y16F_dir = os.path.join(train_Y16F_dir, 'Rt')
os.makedirs(Rt_Y16F_dir, exist_ok=True)
Lt_Y16F_dir = os.path.join(train_Y16F_dir, 'Lt')
os.makedirs(Lt_Y16F_dir, exist_ok=True)


train_Y16M_dir = os.path.join(Y16_dir, '16Y - M')
os.makedirs(train_Y16M_dir, exist_ok=True)

Both_Y16M_dir = os.path.join(train_Y16M_dir, 'Both')
os.makedirs(Both_Y16M_dir, exist_ok=True)
Rt_Y16M_dir = os.path.join(train_Y16M_dir, 'Rt')
os.makedirs(Rt_Y16M_dir, exist_ok=True)
Lt_Y16M_dir = os.path.join(train_Y16M_dir, 'Lt')
os.makedirs(Lt_Y16M_dir, exist_ok=True)

# %%
train_Y17F_dir = os.path.join(Y17_dir, '17Y - F')
os.makedirs(train_Y17F_dir, exist_ok=True)
Both_Y17F_dir = os.path.join(train_Y17F_dir, 'Both')
os.makedirs(Both_Y17F_dir, exist_ok=True)
Rt_Y17F_dir = os.path.join(train_Y17F_dir, 'Rt')
os.makedirs(Rt_Y17F_dir, exist_ok=True)
Lt_Y17F_dir = os.path.join(train_Y17F_dir, 'Lt')
os.makedirs(Lt_Y17F_dir, exist_ok=True)


train_Y17M_dir = os.path.join(Y17_dir, '17Y - M')
os.makedirs(train_Y17M_dir, exist_ok=True)

Both_Y17M_dir = os.path.join(train_Y17M_dir, 'Both')
os.makedirs(Both_Y17M_dir, exist_ok=True)
Rt_Y17M_dir = os.path.join(train_Y17M_dir, 'Rt')
os.makedirs(Rt_Y17M_dir, exist_ok=True)
Lt_Y17M_dir = os.path.join(train_Y17M_dir, 'Lt')
os.makedirs(Lt_Y17M_dir, exist_ok=True)

# %%
train_Y18F_dir = os.path.join(Y18_dir, '18Y - F')
os.makedirs(train_Y18F_dir, exist_ok=True)
Both_Y18F_dir = os.path.join(train_Y18F_dir, 'Both')
os.makedirs(Both_Y18F_dir, exist_ok=True)
Rt_Y18F_dir = os.path.join(train_Y18F_dir, 'Rt')
os.makedirs(Rt_Y18F_dir, exist_ok=True)
Lt_Y18F_dir = os.path.join(train_Y18F_dir, 'Lt')
os.makedirs(Lt_Y18F_dir, exist_ok=True)


train_Y18M_dir = os.path.join(Y18_dir, '18Y - M')
os.makedirs(train_Y18M_dir, exist_ok=True)

Both_Y18M_dir = os.path.join(train_Y18M_dir, 'Both')
os.makedirs(Both_Y18M_dir, exist_ok=True)
Rt_Y18M_dir = os.path.join(train_Y18M_dir, 'Rt')
os.makedirs(Rt_Y18M_dir, exist_ok=True)
Lt_Y18M_dir = os.path.join(train_Y18M_dir, 'Lt')
os.makedirs(Lt_Y18M_dir, exist_ok=True)

# %%
train_Y19F_dir = os.path.join(Y19_dir, '19Y - F')
os.makedirs(train_Y19F_dir, exist_ok=True)
Both_Y19F_dir = os.path.join(train_Y19F_dir, 'Both')
os.makedirs(Both_Y19F_dir, exist_ok=True)
Rt_Y19F_dir = os.path.join(train_Y19F_dir, 'Rt')
os.makedirs(Rt_Y19F_dir, exist_ok=True)
Lt_Y19F_dir = os.path.join(train_Y19F_dir, 'Lt')
os.makedirs(Lt_Y19F_dir, exist_ok=True)


train_Y19M_dir = os.path.join(Y19_dir, '19Y - M')
os.makedirs(train_Y19M_dir, exist_ok=True)

Both_Y19M_dir = os.path.join(train_Y19M_dir, 'Both')
os.makedirs(Both_Y19M_dir, exist_ok=True)
Rt_Y19M_dir = os.path.join(train_Y19M_dir, 'Rt')
os.makedirs(Rt_Y19M_dir, exist_ok=True)
Lt_Y19M_dir = os.path.join(train_Y19M_dir, 'Lt')
os.makedirs(Lt_Y19M_dir, exist_ok=True)

# %%
train_Y20F_dir = os.path.join(Y20_dir, '20Y - F')
os.makedirs(train_Y20F_dir, exist_ok=True)
Both_Y20F_dir = os.path.join(train_Y20F_dir, 'Both')
os.makedirs(Both_Y20F_dir, exist_ok=True)
Rt_Y20F_dir = os.path.join(train_Y20F_dir, 'Rt')
os.makedirs(Rt_Y20F_dir, exist_ok=True)
Lt_Y20F_dir = os.path.join(train_Y20F_dir, 'Lt')
os.makedirs(Lt_Y20F_dir, exist_ok=True)


train_Y20M_dir = os.path.join(Y20_dir, '20Y - M')
os.makedirs(train_Y20M_dir, exist_ok=True)

Both_Y20M_dir = os.path.join(train_Y20M_dir, 'Both')
os.makedirs(Both_Y20M_dir, exist_ok=True)
Rt_Y20M_dir = os.path.join(train_Y20M_dir, 'Rt')
os.makedirs(Rt_Y20M_dir, exist_ok=True)
Lt_Y20M_dir = os.path.join(train_Y20M_dir, 'Lt')
os.makedirs(Lt_Y20M_dir, exist_ok=True)

# %%
train_Y21F_dir = os.path.join(Y21_dir, '21Y - F')
os.makedirs(train_Y21F_dir, exist_ok=True)
Both_Y21F_dir = os.path.join(train_Y21F_dir, 'Both')
os.makedirs(Both_Y21F_dir, exist_ok=True)
Rt_Y21F_dir = os.path.join(train_Y21F_dir, 'Rt')
os.makedirs(Rt_Y21F_dir, exist_ok=True)
Lt_Y21F_dir = os.path.join(train_Y21F_dir, 'Lt')
os.makedirs(Lt_Y21F_dir, exist_ok=True)


train_Y21M_dir = os.path.join(Y21_dir, '21Y - M')
os.makedirs(train_Y21M_dir, exist_ok=True)

Both_Y21M_dir = os.path.join(train_Y21M_dir, 'Both')
os.makedirs(Both_Y21M_dir, exist_ok=True)
Rt_Y21M_dir = os.path.join(train_Y21M_dir, 'Rt')
os.makedirs(Rt_Y21M_dir, exist_ok=True)
Lt_Y21M_dir = os.path.join(train_Y21M_dir, 'Lt')
os.makedirs(Lt_Y21M_dir, exist_ok=True)

# %%
train_Y22F_dir = os.path.join(Y22_dir, '22Y - F')
os.makedirs(train_Y22F_dir, exist_ok=True)
Both_Y22F_dir = os.path.join(train_Y22F_dir, 'Both')
os.makedirs(Both_Y22F_dir, exist_ok=True)
Rt_Y22F_dir = os.path.join(train_Y22F_dir, 'Rt')
os.makedirs(Rt_Y22F_dir, exist_ok=True)
Lt_Y22F_dir = os.path.join(train_Y22F_dir, 'Lt')
os.makedirs(Lt_Y22F_dir, exist_ok=True)


train_Y22M_dir = os.path.join(Y22_dir, '22Y - M')
os.makedirs(train_Y22M_dir, exist_ok=True)

Both_Y22M_dir = os.path.join(train_Y22M_dir, 'Both')
os.makedirs(Both_Y22M_dir, exist_ok=True)
Rt_Y22M_dir = os.path.join(train_Y22M_dir, 'Rt')
os.makedirs(Rt_Y22M_dir, exist_ok=True)
Lt_Y22M_dir = os.path.join(train_Y22M_dir, 'Lt')
os.makedirs(Lt_Y22M_dir, exist_ok=True)

# %%
train_Y23F_dir = os.path.join(Y23_dir, '23Y - F')
os.makedirs(train_Y23F_dir, exist_ok=True)
Both_Y23F_dir = os.path.join(train_Y23F_dir, 'Both')
os.makedirs(Both_Y23F_dir, exist_ok=True)
Rt_Y23F_dir = os.path.join(train_Y23F_dir, 'Rt')
os.makedirs(Rt_Y23F_dir, exist_ok=True)
Lt_Y23F_dir = os.path.join(train_Y23F_dir, 'Lt')
os.makedirs(Lt_Y23F_dir, exist_ok=True)


train_Y23M_dir = os.path.join(Y23_dir, '23Y - M')
os.makedirs(train_Y23M_dir, exist_ok=True)

Both_Y23M_dir = os.path.join(train_Y23M_dir, 'Both')
os.makedirs(Both_Y23M_dir, exist_ok=True)
Rt_Y23M_dir = os.path.join(train_Y23M_dir, 'Rt')
os.makedirs(Rt_Y23M_dir, exist_ok=True)
Lt_Y23M_dir = os.path.join(train_Y23M_dir, 'Lt')
os.makedirs(Lt_Y23M_dir, exist_ok=True)

# %%
train_Y24F_dir = os.path.join(Y24_dir, '24Y - F')
os.makedirs(train_Y24F_dir, exist_ok=True)
Both_Y24F_dir = os.path.join(train_Y24F_dir, 'Both')
os.makedirs(Both_Y24F_dir, exist_ok=True)
Rt_Y24F_dir = os.path.join(train_Y24F_dir, 'Rt')
os.makedirs(Rt_Y24F_dir, exist_ok=True)
Lt_Y24F_dir = os.path.join(train_Y24F_dir, 'Lt')
os.makedirs(Lt_Y24F_dir, exist_ok=True)


train_Y24M_dir = os.path.join(Y24_dir, '24Y - M')
os.makedirs(train_Y24M_dir, exist_ok=True)

Both_Y24M_dir = os.path.join(train_Y24M_dir, 'Both')
os.makedirs(Both_Y24M_dir, exist_ok=True)
Rt_Y24M_dir = os.path.join(train_Y24M_dir, 'Rt')
os.makedirs(Rt_Y24M_dir, exist_ok=True)
Lt_Y24M_dir = os.path.join(train_Y24M_dir, 'Lt')
os.makedirs(Lt_Y24M_dir, exist_ok=True)

# %%
train_Y25F_dir = os.path.join(Y25_dir, '25Y - F')
os.makedirs(train_Y25F_dir, exist_ok=True)
Both_Y25F_dir = os.path.join(train_Y25F_dir, 'Both')
os.makedirs(Both_Y25F_dir, exist_ok=True)
Rt_Y25F_dir = os.path.join(train_Y25F_dir, 'Rt')
os.makedirs(Rt_Y25F_dir, exist_ok=True)
Lt_Y25F_dir = os.path.join(train_Y25F_dir, 'Lt')
os.makedirs(Lt_Y25F_dir, exist_ok=True)


train_Y25M_dir = os.path.join(Y25_dir, '25Y - M')
os.makedirs(train_Y25M_dir, exist_ok=True)

Both_Y25M_dir = os.path.join(train_Y25M_dir, 'Both')
os.makedirs(Both_Y25M_dir, exist_ok=True)
Rt_Y25M_dir = os.path.join(train_Y25M_dir, 'Rt')
os.makedirs(Rt_Y25M_dir, exist_ok=True)
Lt_Y25M_dir = os.path.join(train_Y25M_dir, 'Lt')
os.makedirs(Lt_Y25M_dir, exist_ok=True)
